# %% [markdown]
# <a href="https://colab.research.google.com/github/purduelamm/purdue_me597_iiot/blob/main/lab/lab0/L0_Colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 0.1 Edge Computer and Headless Environment Setup

# %% [markdown]
# ##Learning Goals
#
# Students will be able to:
#
# 1.   Model the essential steps to setup network connection to Raspberry Pi
# 2.   Contrast the different network connection options available for Raspberry Pi
# 3.   Perform basic setup and get access to Raspberry Pi in headless system

# %% [markdown]
# ## 1.1 Introduction
#
# Headless and remote access allows us to control and manage the edge device without hardware interface and visiting the site. In this lab, you will do basic setup and make the wireless or wired connection of Raspberry Pi to a network and access it using SSH and VNC software.

# %% [markdown]
# ## 1.2 Access to Raspberry Pi using SSH
#
# In this section we will access Raspberry Pi using SSH via the ethernet cable. Follow the steps below.
#
# 1.   Run CMD on your laptop
# 2.   Type *ssh pi@firstnamelastname.local* for Host Name
# 3.   Enter your password. (If you forgot, you need to install OS again...)
#
# You will see the terminal window of Raspberry pi as Figure 1. This is SSH access to headless computer. Through SSH, you can do all: setup, manage file systems, write code, install packages, and so on.
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_update/Lab0_fig1.PNG?raw=true" width="100%">
#
# *Figure 1 SSH access to Raspberry Pi*
#
# (trouble shooting) If your computer has previously connected to another Raspberry Pi using the same hostname, remove the saved SSH host key before reconnecting:
# `ssh-keygen -R <hostname>.local`

# %% [markdown]
# ## 1.3 Raspberry Pi Network Stability
#
# In this section we will enhance the local network connectivity between the Raspberry Pi and your local PC using SSH. Follow the steps below.
#
# 0. From 1.2, you would have already accessed the CLI (Command Line Interface) of your Raspberry Pi in your PC Windows terminal.
# 1. Type the followin in the CLI. This will allow you to see the networks that are available in you Raspberry Pi
#
#     `nmcli connection show`
#
# 2. Please note the NAME, UUID, TYPE, and DEVICE information that appears. Refer to the DEVICE that is "eth0" and make note of its NAME.
#
# 3. Type the following in the CLI. This will allow you to change your Raspberry Pi's static ip and get restore default settings.
#     Make sure to edit "netplan-eth0" into the name noted in step 2.
#
#     `sudo nmcli con modify "netplan-eth0" ipv4.method manual ipv4.addresses 192.168.50.2/24 ipv4.gateway "" ipv4.dns "" ipv4.never-default yes`
#
#     for example) If the note NAME in step 2 was "Wired connection 1", edit as below
#
#     `sudo nmcli con modify "Wired connection 1" ipv4.method manual ipv4.addresses 192.168.50.2/24 ipv4.gateway "" ipv4.dns "" ipv4.never-default yes`
#
# 4. Type the following in CLI. This will restart the network connection.
#
#     `sudo nmcli con down "netplan-eth0"; sudo nmcli con up "netplan-eth0"`
#
# 5. Now in your PC, change your PC's ip (networked with Raspi) as described in the figure below.
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_summer/Lab0_fig3.png?raw=true" width="100%">
#
# *Figure 2 PC ethernet ip settings*
#
# 6. Open a new termial (cmd) in your PC and run below. This will allow pinging from raspi.
#
#     `netsh advfirewall firewall add rule name="Allow Ping from Raspberry Pi" dir=in action=allow protocol=icmpv4:8,any remoteip=192.168.50.2 profile=any`

# %% [markdown]
# ### Task 1.1
#
# Capture your terminal window after login to Raspberry Pi as Figure 1 and attach it to the report below:
#
# ---
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# ## 1.4 Basic setup of Raspberry Pi
#
# Now, you can access Raspberry Pi from your laptop using SSH via an Ethernet cable. Even if your laptop can use the Internet, Raspberry Pi is not because we haven't make the Internet connection yet. We will deal with the Internet sharing in the next section. Before that, let's do basic configurations for Raspberry Pi such as 'Country', 'Keyboard', 'Timezone', and so on.
# <br></br>
#
# The essential configurations can be set up using 'sudo raspi-config' command.
#
# ---
# **<img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/icon_RaspberryPi.png?raw=tru" width="20">Raspberry Pi - Linux - Terminal**
#
# `sudo raspi-config`
#
# ---
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_update/Lab0_fig2.PNG?raw=true" width="100%">
#
# *Figure 3 Raspberry Pi Configuration Tool*
#
#   *※ sudo is a Linux command meaning 'super user do'. This command means execute raspi-config command in super user (root/admin) privilege.*
#
# <br></br>
#
# Figure 2 shows an interface windows of *'raspi-config'*. You use keyboard (number keys, arrow keys, Enter, ESC, Space, etc.) to manipulate the configuration setting. Try to move using keyboard. For the basic configurations, follow the steps below.
#
#
# 1.   Enable 'VNC' interface
#     > Location: Interface Options/VNC
#
# 2.   Finish (save) raspi-config
#
#   *※ Raspberry Pi may ask you 'Would you like to reboot now?' If you choose <Yes>, you can skip step 7.*
#
# 3.  Reboot Raspberry Pi using the command below
#
#
# ---
# **<img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/icon_RaspberryPi.png?raw=tru" width="20">Raspberry Pi - Linux - Terminal**
#
# `sudo reboot`
#
# ---

# %% [markdown]
# ### Task 1.2
#
# Capture your terminal window after rebooting as Figure 1 and attach it to the report below:
#
#
# ---
#
# Place your screenshot here.
#
# ---

# %% [markdown]
# ### Task 1.3
#
# Capture your ping test results from both machines each other and attach those to the report below:
#
#   *※ If you want to halt a process or execution in the terminal, the shortcut is Ctrl+c.*
#
# ---
#
# Place your screenshot here.
#
# ---

# %% [markdown]
# ## 1.5 VNC access using VNC Viewer
#
# In Prelab 0, you’ve installed VNC Viewer on your laptop. Follow the direction below. If you are using Linux, use Remmina instead of VNC Viewer.
#
# 1. Run VNC Viewer on your laptop (TigerVNC/RealVNC Whether is fine)
# 2. Type your IP address (`192.168.50.2`) or the host name of the Raspberry PI (johndoe.local) and then hit *'Enter'*
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S25_update/lab0_fig10.png?raw=true" width="50%">
#
# *Figure 4 VNC Viewer connection ipm in this case, local-ip*
#
# 3. Type your login credential (username and password) on the pop-up window
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/lab0_fig0-11.png?raw=true" width="50%">
#
# *Figure 5 Raspberry Pi VNC Viewer connection ID and password*
#
#
#
# <br></br>
#
# Now you you will see the familiar screen like Figure 5. Play with it!
#
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/lab0_fig0-14.png?raw=true" width="50%">
#
# *Figure 6 Raspberry Pi GUI using VNC Viewer*
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/prelab0_fig10.png?raw=true" width="50%">
#
# *Figure 7 Taskbar Icons of Raspberry Pi GUI*
#
# <br></br>

# %% [markdown]
# ## 1.6 Internet Connection with VNC
#
# We will now connect to the internet in VNC. Follow the steps below.
#
# **[Connection to PAL3.0 - for on-campus use]
#
# 0.  Notice that there is a Up & Down arrow in the top-right corner of your VNC screen, this is the internet settings. Check if have "PAL3.0"
#
# 1.  run the code below. This is delete all initial settings related to internet connection using "PAL3.0"
#
#     `sudo nmcli con delete "PAL3.0" 2>/dev/null;`
#
# 2.  run the code below. make sure to change "<your_purdue_ID>" in the text.
#
#     `sudo nmcli con add type wifi ifname wlan0 con-name "PAL3.0" ssid "PAL3.0" wifi-sec.key-mgmt wpa-eap 802-1x.eap peap 802-1x.identity “<your_purdue_ID>" 802-1x.phase2-auth mschapv2 802-1x.system-ca-certs no && sudo nmcli --ask con up "PAL3.0"`
#
#     example)
#
#     `sudo nmcli con add type wifi ifname wlan0 con-name "PAL3.0" ssid "PAL3.0" wifi-sec.key-mgmt wpa-eap 802-1x.eap peap 802-1x.identity “sim46" 802-1x.phase2-auth mschapv2 802-1x.system-ca-certs no && sudo nmcli --ask con up "PAL3.0"`
#
# 3.  If code in step 2 has issues, change the wifi settings as noted in the figure below.
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_summer/Lab0_fig8.png?raw=true" width="50%">
#
# *Figure 8 WIFI settings for PAL3.0*
#
# Now you have internet connection!
#
# **[Connection to general WIFI - for home use]
# 0.  Notice that there is a Up & Down arrow in the top-right corner of your VNC screen, this is the internet settings. Connect to your WIFI as in figure below.
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_summer/Lab0_fig9.png?raw=true" width="50%">
#
# *Figure 9 General wifi connection*

# %% [markdown]
# ### Task 1.4
#
# Capture your ping test results from the Raspberry Pi to Purdue webpage (purdue.edu, `ping purdue.edu`) and attach it to the report below:
#
#   *※ If want to halt a process or execution in the terminal, the shortcut is Ctrl+c.*
#
# ---
#
# Place your screenshot here.
#
# ---

# %% [markdown]
# ## 1.7 Raspberry Pi terminal and packages
#
#
# The terminal is a useful application. It allows you to navigate file directories and control your Raspberry Pi using typed commands instead of clicking on menu options. It’s often in many tutorials and project guides, including the ones on our website.
#
# In addition, we can take advantage of Raspberry Pi packages. In the terminal, we can install, uninstall, and manage the packages.
#
# Let’s try to install a Linux package. Install *‘tmux’* package on your Raspberry Pi using command below.
#
# ---
#
# **<img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/icon_RaspberryPi.png?raw=tru" width="20">Raspberry Pi - Terminal**
#
# `sudo apt install tmux -y`
#
# ---
#
# If you don’t know or are unclear about a Linux command, google it! Or you can see a manual using command ‘man packagename’such as below. Try ‘man tmux’.
#
# ---
#
# **<img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img/icon_RaspberryPi.png?raw=tru" width="20"> Raspberry Pi - Terminal**
#
# `man apt`
#
# ---
#
# * This shows the manual document of ‘apt’ command.
# * Tips: to change page, press PgUp or PgDn and to exit, press 'q'.
#
# ![picture](https://github.com/hewp84/tinyml/blob/main/img/L1_Figure2.png?raw=true)
#
# *Figure 10 Manual of 'apt' command*
#
#
# It is recommended to go through a Raspberry Pi terminal guideline (https://raspberrypi-guide.github.io/programming/working-with-the-command-line, available on Jan. 13, 2023).
#
#
# Try update and upgrade packages using `sudo apt update` and `sudo apt upgrade -y`.
#
# <br></br>

# %% [markdown]
# ### Task 1.5
#
# Capture your terminal after upgrading packages using `apt` command and attach it in the space below:
#
#
# ---
#
# Place your screenshot in here.
#
# ---

# %% [markdown]
# ## 1.8 Looking Forward to Lab 0.2: Network-Based Remote Access
#
# In Lab 0.1, the laptop and Raspberry Pi were connected primarily through a direct Ethernet connection. Lab 0.2 introduces two network tools used for different purposes:
#
# - **Purdue Cisco VPN:** Allows an off-campus or online student to enter the Purdue network logically and access resources or devices that are available within the Purdue network.
# - **Tailscale VPN:** Creates a private device-to-device network between the laptop and Raspberry Pi. It allows the devices to communicate through their Tailscale addresses even when direct communication is restricted on a secured network such as PAL 3.0.
#
# Continue to **L0_Colab2** for Purdue Cisco VPN and Tailscale setup.
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_summer/Lab0_fig10.png?raw=true" width="50%">
#
# *Figure 11 Connection as in Task 1.4*
#
# <img src="https://github.com/purduelamm/purdue_me597_iiot/blob/main/lab/img_S26_summer/Lab0_fig11.png?raw=true" width="50%">
#
# *Figure 12 Connection to be made in next session using VPN*

# %% [markdown]
# <br></br>
#
# Please continue to [Lab 0.2 here](https://colab.research.google.com/github/purduelamm/purdue_me597_iiot/blob/main/lab/lab0/L0_Colab2.ipynb).
